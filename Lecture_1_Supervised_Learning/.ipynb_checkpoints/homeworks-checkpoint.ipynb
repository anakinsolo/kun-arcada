# %% [markdown]
# * Homework binary classification: https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients

# %%
* regression https://archive.ics.uci.edu/ml/datasets/Superconductivty+Data

# %%
* multiclass & binary https://archive.ics.uci.edu/ml/datasets/Drug+consumption+%28quantified%29
